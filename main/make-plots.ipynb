# %%
import modelframe as mf
import models as ms
import numpy as np
import matplotlib.pyplot as plt
import plotutilities as pu
import datautilities as du

# %%
datadir = "../model/model-binary-weighted-001"

frame = mf.GlitchModel(ms.GlitchClassifier(), None, None)
frame.read_result_data(datadir)

fig,ax = pu.plot_performance(frame)
fig.savefig(f"{datadir}/figures/performance-overview-1.pdf", bbox_inches = "tight")
fig.savefig(f"{datadir}/figures/performance-overview-1.png", bbox_inches = "tight")

fig, ax = pu.plot_recall_matrix(frame)
fig.savefig(f"{datadir}/figures/recall-matrix-1.pdf", bbox_inches = "tight")
fig.savefig(f"{datadir}/figures/recall-matrix-1.png", bbox_inches = "tight")

fig, ax = pu.plot_precision_matrix(frame)
fig.savefig(f"{datadir}/figures/precision-matrix-1.pdf", bbox_inches = "tight")
fig.savefig(f"{datadir}/figures/precision-matrix-1.png", bbox_inches = "tight")

fig, ax = pu.plot_accuracy_matrix(frame)
fig.savefig(f"{datadir}/figures/accuracy-matrix-1.pdf", bbox_inches = "tight")
fig.savefig(f"{datadir}/figures/accuracy-matrix-1.png", bbox_inches = "tight")
# Out:
# Model settings and results successfully loaded.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       3 frame = mf.GlitchModel(ms.GlitchClassifier(), None, None)
#       4 frame.read_result_data(datadir)
# ----> 6 fig,ax = pu.plot_performance(frame)
#       7 fig.savefig(f"{datadir}/figures/performance-overview-1.pdf", bbox_inches = "tight")
#       8 fig.savefig(f"{datadir}/figures/performance-overview-1.png", bbox_inches = "tight")
#
# File ~/Documents/Courses/2024-1.0 Machine Learning/ml-gw-project/main/plotutilities.py:157, in plot_performance(frame)
#     155 ax[0,0].plot(epochs, frame.training_loss, label = r"Training Loss",zorder = 1, color = "tab:red")
#     156 ax[0,0].plot(epochs, frame.validiation_loss, label = r"Validation Loss",zorder = 1, color = "tab:blue")
# --> 157 ax[1,0].plot(epochs, frame.accuracy, label = r"Accuracy",zorder = 1, color = "k")
#     158 ax[1,0].plot(epochs, frame.precision, label = r"Precision",zorder = 1, color = "tab:red")
#     159 ax[1,0].plot(epochs, frame.recall, label = r"Recall",zorder = 1, color = "tab:blue")
#
# File ~/.python-config/virtual-environments/base/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File ~/.python-config/virtual-environments/base/lib/python3.11/site-packages/matplotlib/axes/_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File ~/.python-config/virtual-environments/base/lib/python3.11/site-packages/matplotlib/axes/_base.py:494, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     491     axes.yaxis.update_units(y)
#     493 if x.shape[0] != y.shape[0]:
# --> 494     raise ValueError(f"x and y must have same first dimension, but "
#     495                      f"have shapes {x.shape} and {y.shape}")
#     496 if x.ndim > 2 or y.ndim > 2:
#     497     raise ValueError(f"x and y can be no greater than 2D, but have "
#     498                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (250,) and (0,)

# %%
datadir = "../model/model-binary-undersampled-001"

frame = mf.GlitchModel(ms.GlitchClassifier(), None, None)
frame.read_result_data(datadir)

fig,ax = pu.plot_performance(frame)
fig.savefig(f"{datadir}/figures/performance-overview-1.pdf", bbox_inches = "tight")
fig.savefig(f"{datadir}/figures/performance-overview-1.png", bbox_inches = "tight")

fig, ax = pu.plot_recall_matrix(frame)
fig.savefig(f"{datadir}/figures/recall-matrix-1.pdf", bbox_inches = "tight")
fig.savefig(f"{datadir}/figures/recall-matrix-1.png", bbox_inches = "tight")

fig, ax = pu.plot_precision_matrix(frame)
fig.savefig(f"{datadir}/figures/precision-matrix-1.pdf", bbox_inches = "tight")
fig.savefig(f"{datadir}/figures/precision-matrix-1.png", bbox_inches = "tight")

fig, ax = pu.plot_accuracy_matrix(frame)
fig.savefig(f"{datadir}/figures/accuracy-matrix-1.pdf", bbox_inches = "tight")
fig.savefig(f"{datadir}/figures/accuracy-matrix-1.png", bbox_inches = "tight")

# %%
datadir = "../model/model-multi-uniform-001"

frame = mf.GlitchModel(ms.GlitchClassifier(), None, None)
frame.read_result_data(datadir)

fig,ax = pu.plot_performance(frame)
fig.savefig(f"{datadir}/figures/performance-overview-1.pdf", bbox_inches = "tight")
fig.savefig(f"{datadir}/figures/performance-overview-1.png", bbox_inches = "tight")

fig, ax = pu.plot_recall_matrix(frame)
fig.savefig(f"{datadir}/figures/recall-matrix-1.pdf", bbox_inches = "tight")
fig.savefig(f"{datadir}/figures/recall-matrix-1.png", bbox_inches = "tight")

fig, ax = pu.plot_precision_matrix(frame)
fig.savefig(f"{datadir}/figures/precision-matrix-1.pdf", bbox_inches = "tight")
fig.savefig(f"{datadir}/figures/precision-matrix-1.png", bbox_inches = "tight")

fig, ax = pu.plot_accuracy_matrix(frame)
fig.savefig(f"{datadir}/figures/accuracy-matrix-1.pdf", bbox_inches = "tight")
fig.savefig(f"{datadir}/figures/accuracy-matrix-1.png", bbox_inches = "tight")
